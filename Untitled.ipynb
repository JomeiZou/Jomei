# %%
import numpy as np
a = [1,2,3,4]
b = np.array(a)
print(b)
display(b)
print(type(b))
c = [[1,2],[3,4]]
d = np.array(c)
display(d)
display(d.shape)
# Out:
# [1 2 3 4]
# array([1, 2, 3, 4])
# <class 'numpy.ndarray'>
# array([[1, 2],
#        [3, 4]])
# (2, 2)

# %%
display(b.ndim)
display(d.ndim)
# Out:
# 1
# 2

# %%
display(b.shape)
display(d.shape)
# Out:
# (4,)
# (2, 2)

# %%
display(b.size)
display(d.size)
# Out:
# 4
# 4

# %%
display(b.dtype)
display(d.dtype)
# Out:
# dtype('int32')
# dtype('int32')

# %%
jomei = [9,8,7,6]
zoucunna = [1.1,1.2,1.3]
jomei_array =np.array(jomei)
zoucunna_array = np.array(zoucunna)
display(jomei_array.dtype,zoucunna_array.dtype)
# Out:
# dtype('int32')
# dtype('float64')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
jakson = plt.imread('C:\\Users\\User\\Desktop\\zhuomian\\bizhi\\TFBOYS\\W020170627298041174801.jpeg')
display(jakson)
# Out:
# array([[[192, 157, 125],
#         [193, 158, 126],
#         [196, 161, 129],
#         ...,
#         [222, 212, 163],
#         [223, 213, 164],
#         [223, 213, 164]],
#
#        [[190, 155, 123],
#         [192, 157, 125],
#         [194, 159, 127],
#         ...,
#         [223, 213, 164],
#         [224, 214, 165],
#         [225, 215, 166]],
#
#        [[189, 154, 122],
#         [191, 156, 124],
#         [194, 159, 127],
#         ...,
#         [223, 213, 164],
#         [224, 214, 165],
#         [225, 215, 166]],
#
#        ...,
#
#        [[159, 131, 146],
#         [123,  95, 110],
#         [109,  81,  96],
#         ...,
#         [  5,  35, 125],
#         [  5,  35, 123],
#         [  7,  34, 123]],
#
#        [[160, 132, 147],
#         [123,  95, 110],
#         [108,  80,  95],
#         ...,
#         [  5,  35, 125],
#         [  7,  34, 125],
#         [  7,  34, 125]],
#
#        [[161, 133, 148],
#         [123,  95, 110],
#         [107,  79,  94],
# ...

# %%
plt.imshow(jakson)

# %%
jakson_change = jakson.copy()
jakson_change.shape
# Out:
# (640, 640, 3)

# %%
for i in range(640):
    for j in range(640):
        for k in range(3):
            if jakson_change[i][j][k]  == 123:
                jakson_change[i][j][k] == 5

# %%
jakson_change
# Out:
# array([[[192, 157, 125],
#         [193, 158, 126],
#         [196, 161, 129],
#         ...,
#         [222, 212, 163],
#         [223, 213, 164],
#         [223, 213, 164]],
#
#        [[190, 155, 123],
#         [192, 157, 125],
#         [194, 159, 127],
#         ...,
#         [223, 213, 164],
#         [224, 214, 165],
#         [225, 215, 166]],
#
#        [[189, 154, 122],
#         [191, 156, 124],
#         [194, 159, 127],
#         ...,
#         [223, 213, 164],
#         [224, 214, 165],
#         [225, 215, 166]],
#
#        ...,
#
#        [[159, 131, 146],
#         [123,  95, 110],
#         [109,  81,  96],
#         ...,
#         [  5,  35, 125],
#         [  5,  35, 123],
#         [  7,  34, 123]],
#
#        [[160, 132, 147],
#         [123,  95, 110],
#         [108,  80,  95],
#         ...,
#         [  5,  35, 125],
#         [  7,  34, 125],
#         [  7,  34, 125]],
#
#        [[161, 133, 148],
#         [123,  95, 110],
#         [107,  79,  94],
# ...

# %%
plt.imshow(jakson_change)
